# %%
import branca
import folium
import pandas as pd
import geopandas as gpd
from folium import plugins
from branca import colormap as cm
from ipywidgets import interact, fixed
# Out:
# Unable to open EPSG support file gcs.csv.  Try setting the GDAL_DATA environment variable to point to the directory containing EPSG csv files.

# %%
karelia = gpd.read_file('karelia.geojson', encoding='utf8')
columns = ['name', 'population', 'geometry']
karelia = karelia[columns].dropna()
karelia.head()
# Out:
#                     name population  \
# 0     Калевальский район       7525
# 1         Лоухский район      12872
# 2  Медвежьегорский район      29874
# 3       Муезерский район      11214
# 4    Лахденпохский район      13712
#
#                                             geometry
# 0  POLYGON ((29.9307181 65.6787257, 29.900922 65....
# 1  POLYGON ((29.9813464 66.02932730000001, 29.984...
# 2  POLYGON ((35.6805005 62.1908169, 35.7515598 62...
# 3  POLYGON ((31.4390222 63.0362137, 31.8226383 63...
# 4  POLYGON ((29.7514237 61.1723842, 29.7547277 61...

# %%
to_swap = {"Петрозаводский городской округ": "Петрозаводск", "Костомукшский городской округ": "Костомукша"}
karelia.name = karelia.name.apply(lambda x: str(x).rstrip("район").rstrip(" "))
karelia.name = karelia.name.apply(lambda x: to_swap[x] if x in to_swap else x)
karelia.head()
# Out:
#               name population  \
# 0     Калевальский       7525
# 1         Лоухский      12872
# 2  Медвежьегорский      29874
# 3       Муезерский      11214
# 4    Лахденпохский      13712
#
#                                             geometry
# 0  POLYGON ((29.9307181 65.6787257, 29.900922 65....
# 1  POLYGON ((29.9813464 66.02932730000001, 29.984...
# 2  POLYGON ((35.6805005 62.1908169, 35.7515598 62...
# 3  POLYGON ((31.4390222 63.0362137, 31.8226383 63...
# 4  POLYGON ((29.7514237 61.1723842, 29.7547277 61...

# %%
fire_df = pd.read_csv('firemen_karelia_restruct.csv')
fire_df.head()
# Out:
#           Район   Год  Количество пожаров  Материальный ущерб (тыс. руб.)  \
# 0   Беломорский  2015                  42                            1009
# 1   Беломорский  2016                  38                            1150
# 2   Беломорский  2017                  34                             262
# 3   Беломорский  2018                  32                             240
# 4  Калевальский  2015                  25                            1873
#
#    Количество пострадавших  Количество ДПФ  Количество добровольцев  \
# 0                        7              32                      181
# 1                        5              31                      183
# 2                        6              34                      220
# 3                        4              32                      214
# 4                        2              14                      101
#
#    Количество выездов добровольцев на пожары  Загорания  \
# 0                                          6          0
# 1                                          9          6
# 2                                          4          3
# 3                                          5          0
# 4                                         12          0
#
#    Количество обученных добровольцев          Субъект РФ
# 0                                128  Республика Карелия
# 1                                135  Республика Карелия
# 2                                173  Республика Карелия
# 3                                185  Республика Карелия
# 4                                 28  Республика Карелия

# %%
data = pd.merge(karelia, fire_df, how="left", left_on="name", right_on="Район").drop(columns=["Район"])
data.head()
# Out:
#            name population                                           geometry  \
# 0  Калевальский       7525  POLYGON ((29.9307181 65.6787257, 29.900922 65....
# 1  Калевальский       7525  POLYGON ((29.9307181 65.6787257, 29.900922 65....
# 2  Калевальский       7525  POLYGON ((29.9307181 65.6787257, 29.900922 65....
# 3  Калевальский       7525  POLYGON ((29.9307181 65.6787257, 29.900922 65....
# 4      Лоухский      12872  POLYGON ((29.9813464 66.02932730000001, 29.984...
#
#       Год  Количество пожаров  Материальный ущерб (тыс. руб.)  \
# 0  2015.0                25.0                          1873.0
# 1  2016.0                25.0                           407.0
# 2  2017.0                20.0                           249.0
# 3  2018.0                14.0                             0.0
# 4  2015.0                31.0                           171.0
#
#    Количество пострадавших  Количество ДПФ  Количество добровольцев  \
# 0                      2.0            14.0                    101.0
# 1                     10.0            14.0                    106.0
# 2                      3.0            15.0                    111.0
# 3                      0.0            15.0                    117.0
# 4                      6.0            22.0                    148.0
#
#    Количество выездов добровольцев на пожары  Загорания  \
# 0                                       12.0        0.0
# 1                                        6.0        0.0
# 2                                        5.0        0.0
# 3                                        0.0        3.0
# 4                                        3.0        0.0
#
#    Количество обученных добровольцев          Субъект РФ
# 0                               28.0  Республика Карелия
# 1                               28.0  Республика Карелия
# 2                               62.0  Республика Карелия
# 3                               83.0  Республика Карелия
# 4                               77.0  Республика Карелия

# %%
data.rename({"Количество пожаров": "fire_count", "Количество ДПФ": "dpf_count",
             "Год": "year"}, axis='columns', inplace=True)
data.year = data.year.astype("int", errors="ignore")

# %%
colormap = cm.linear.YlOrRd_04.scale(
    data.fire_count.quantile(0.05),
    data.fire_count.quantile(0.95)
)

def style_fire(feature):
    val = data.fire_count.iloc[int(feature['id'])]
    out = {
        'weight': 0.8,
        'color': 'black',
        'opacity': 0.6
    }
    if str(val) == 'nan':
        out['fillOpacity'] = 0
    else:
        out['fillColor'] = colormap(val),
        out['fillOpacity'] = 0.6
    return out

def highlight_fire(feature):
    val = data.fire_count.iloc[int(feature['id'])]
    if str(val) == 'nan':
        return {'fillOpacity': 0}
    return {
        'fillOpacity': 0.8,
        'weight':1.4,
    }

# %%
colormap_dpf = cm.linear.YlGn_06.scale(
    data.dpf_count.quantile(0.05),
    data.dpf_count.quantile(0.95)
)

def style_dpf(feature):
    val = data.dpf_count.iloc[int(feature['id'])]
    out = {
        'weight': 0.8,
        'color': 'black',
        'opacity': 0.6
    }
    if str(val) == 'nan':
        out['fillOpacity'] = 0
    else:
        out['fillColor'] = colormap_dpf(val),
        out['fillOpacity'] = 0.6
    return out

def highlight_dpf(feature):
    val = data.dpf_count.iloc[int(feature['id'])]
    if str(val) == 'nan':
        return {'fillOpacity': 0}
    return {
        'fillOpacity': 0.8,
        'weight':1.4,
    }

# %% [markdown]
# <h2>Пример карты для одного года</h2>

# %%
dmap = plugins.DualMap(location=[64, 33], zoom_start=7)
    
tooltip = folium.GeoJsonTooltip(
    fields=["name", "population", "fire_count"],
    aliases=["Район", "Население", "Пожаров"]
)

folium.GeoJson(
    data[data.year == 2015],
    style_function=style_fire,
    highlight_function=highlight_fire,
    tooltip=tooltip
).add_to(dmap.m1)

colormap.caption = "Количество пожаров"
colormap.add_to(dmap.m1)

tooltip_dpf = folium.GeoJsonTooltip(
    fields=["name", "population", "dpf_count"],
    aliases=["Район", "Население", "Добровольных пожарных\nформиров."]
)

folium.GeoJson(
    data[data.year == 2015],
    style_function=style_dpf,
    highlight_function=highlight_dpf,
    tooltip=tooltip_dpf
).add_to(dmap.m2)

colormap_dpf.caption = "Количество ДПФ"
colormap_dpf.add_to(dmap.m1)

dmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2>Интерактивная карта для нескольких годов</h2>
# <p>К сожалению, она не отображается онлайн</p>
# <p>Выглядит это так:</p>
# <img src="interactive.png">

# %%
@interact(location=fixed([64, 33]), zoom_start=fixed(7), Year=(2015, 2018))
def render_map(location, zoom_start, Year):
    dmap = plugins.DualMap(location=location, zoom_start=zoom_start)
    
    tooltip = folium.GeoJsonTooltip(
        fields=["name", "population", "fire_count"],
        aliases=["Район", "Население", "Пожаров"]
    )

    folium.GeoJson(
        data[data.year == Year],
        style_function=style_fire,
        highlight_function=highlight_fire,
        tooltip=tooltip
    ).add_to(dmap.m1)

    colormap.caption = "Количество пожаров"
    colormap.add_to(dmap.m1)
    
    tooltip_dpf = folium.GeoJsonTooltip(
        fields=["name", "population", "dpf_count"],
        aliases=["Район", "Население", "Добровольных пожарных\nформиров."]
    )

    folium.GeoJson(
        data[data.year == Year],
        style_function=style_dpf,
        highlight_function=highlight_dpf,
        tooltip=tooltip_dpf
    ).add_to(dmap.m2)

    colormap_dpf.caption = "Количество ДПФ"
    colormap_dpf.add_to(dmap.m1)
    
    return dmap
# Out:
# interactive(children=(IntSlider(value=2016, description='Year', max=2018, min=2015), Output()), _dom_classes=(…
